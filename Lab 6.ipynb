# %% [markdown]
# # CSE 572: Lab 6
#
# In this lab, you will practice implementing feed-forward network and parameter tuning with k-fold cross valivation.
#
# To execute and make changes to this notebook, click File > Save a copy to save your own version in your Google Drive or Github. Read the step-by-step instructions below carefully. To execute the code, click on each cell below and press the SHIFT-ENTER keys simultaneously or by clicking the Play button.
#
# When you finish executing all code/exercises, save your notebook then download a copy (.ipynb file). Submit the following **three** things:
# 1. a link to your Colab notebook,
# 2. the .ipynb file, and
# 3. a pdf of the executed notebook on Canvas.
#
# To generate a pdf of the notebook, click File > Print > Save as PDF.

# %%
# Import libraries
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# Set the random seed for reproducibility
seed = 0
tf.random.set_seed(seed)

# %% [markdown]
# ## Feed-forward neural networks

# %% [markdown]
# ### Load the dataset
#
# For this example, we will use the [Cleveland Heart Disease dataset](https://archive.ics.uci.edu/ml/datasets/heart+Disease). Review the dataset documentation to learn more about the attributes and other aspects of the dataset. The dataset consists of a CSV file with 303 rows. Each row contains information about a patient. There are 14 attribute columns and one binary class column (`target`) that reports whether or not a patient had a heart disease. We will train a feed-forward neural network model to predict whether or not a given patient has a heart disease based on the attribute values.

# %%
# Load the dataset
data = pd.read_csv("http://storage.googleapis.com/download.tensorflow.org/data/heart.csv")

# %%
# Print sample rows
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
# Print the number of rows and columns
data.shape
# Out:
# (303, 14)

# %% [markdown]
# Split the dataset into three randomly-sampled subsets: training (60%), validation (20%), and test (20%). Use the `seed` variable for the `random_state`.

# %%
train, val, test = np.split(data.sample(frac=1, random_state=seed), [int(.6*len(data)), int(.8*len(data))])

# %% [markdown]
# Print the number of samples in each of the three subsets and the number of instances from each class. For example, for the training set you might print "The training set has __ instances (__ heart disease, __ no disease)".

# %%
# YOUR CODE HERE
num_samples_train = len(train)
num_samples_val = len(val)
num_samples_test = len(test)

num_heart_disease_train = train['target'].sum()
num_no_disease_train = num_samples_train - num_heart_disease_train

num_heart_disease_val = val['target'].sum()
num_no_disease_val = num_samples_val - num_heart_disease_val

num_heart_disease_test = test['target'].sum()
num_no_disease_test = num_samples_test - num_heart_disease_test

# (num_samples_train, num_heart_disease_train, num_no_disease_train), (num_samples_val, num_heart_disease_val, num_no_disease_val), (num_samples_test, num_heart_disease_test, num_no_disease_test)

print(f"The training set has {num_samples_train} instances ({num_heart_disease_train} heart disease, {num_no_disease_train} no disease)")
print(f"The validation set has {num_samples_val} instances ({num_heart_disease_val} heart disease, {num_no_disease_val} no disease)")
print(f"The test set has {num_samples_test} instances ({num_heart_disease_test} heart disease, {num_no_disease_test} no disease)")
# Out:
# The training set has 181 instances (48 heart disease, 133 no disease)
# The validation set has 61 instances (18 heart disease, 43 no disease)
# The test set has 61 instances (17 heart disease, 44 no disease)

# %% [markdown]
# ### Prepare the dataset
#
# Before we can feed this dataset to our model for training and evaluation, we need to perform a few steps to get it ready:
# 1. Convert the dataframes to Dataset objects
# 2. Normalize the numerical feature values
# 3. Binarize the Categorical features by converting to one-hot encodings

# %%
# Convert dataframes to Dataset objects
def dataframe_to_dataset(df, shuffle=True):
    df = df.copy()
    # Remove the target column and store in a separate array
    labels = df.pop('target')
    ds = tf.data.Dataset.from_tensor_slices((dict(df), labels))
    if shuffle:
      ds = ds.shuffle(buffer_size=len(df), reshuffle_each_iteration=False)

    return ds


train_ds_original = dataframe_to_dataset(train)
val_ds_original = dataframe_to_dataset(val)
test_ds_original = dataframe_to_dataset(test)

# %% [markdown]
# The Dataset object yields a tuple containing the input feature vector and target (class value): `(input, target)`. `input` is a dictionary of features and `target` is the value 0 or 1. The code below prints an example instance drawn from the training Dataset object.

# %%
for x, y in train_ds_original.take(1):
    print("Input:", x)
    print("\nTarget:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=63>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=3>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=135>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=252>, 'fbs': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'restecg': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'thalach': <tf.Tensor: shape=(), dtype=int64, numpy=172>, 'exang': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'oldpeak': <tf.Tensor: shape=(), dtype=float64, numpy=0.0>, 'slope': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'ca': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'thal': <tf.Tensor: shape=(), dtype=string, numpy=b'normal'>}
#
# Target: tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# We can use the batch() function in keras to create batches from the full dataset for passing to the model. For the training dataset, we'll define a hyperparameter `batch_size` that we will set. For the validation and test sets, we will make the batch size equivalent to the size of the subset so all samples in that subset are evaluated each time the dataset is evaluated by the model.

# %%
batch_size = 32
train_ds = train_ds_original.batch(batch_size)
val_ds = val_ds_original.batch(val.shape[0])
test_ds = test_ds_original.batch(test.shape[0])

# %% [markdown]
# There are seven categorical features in the dataset: `sex`, `cp`, `fbs`, `restecg`, `exang`, `ca`, and `thal`. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). All of them except `thal` have integer data type while `thal` has String data type. Below we define a function to encode these feature values as one-hot encodings using the [IntegerLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/IntegerLookup) and [StringLookup()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/StringLookup) layers. These layers create look-up tables for mapping a set of arbitrary integers or strings to a one-hot encoding. We use an `is_string` argument to indicate whether we should use the `StringLookup()` for `thal` or the `IntegerLookup()` for the remaining features.

# %%
def encode_categorical_feature(feature, name, dataset, is_string):
    from tensorflow.keras.layers import IntegerLookup
    from tensorflow.keras.layers import StringLookup

    # Create lookup layer to turn categorical features into 1-hot integer encodings
    if is_string:
        lookup = StringLookup(output_mode="binary")
    else:
        lookup = IntegerLookup(output_mode="binary")

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Find the set of possible values and assign them a fixed integer index
    lookup.adapt(feature_ds)

    # Turn the input into integer indices
    encoded_feature = lookup(feature)
    return encoded_feature

# %% [markdown]
# The remaining features in the dataset (`age`, `trestbps`, `chol`, `thalach`, `oldpeak`, and `slope`) are all numerical measurements. You can read more about what these features mean in the [dataset documentation](https://archive.ics.uci.edu/ml/datasets/heart+Disease). We don't need to encode the numerical features, but we do want to scale them to the same range of values (e.g., using standardization or normalization). Below we define a function that uses the [Normalization()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization) layer to standardize the data (subtract the mean and divide by the standard deviation for each feature).

# %%
def normalize(feature, name, dataset):
    from tensorflow.keras.layers import Normalization

    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields the feature of interest
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    norm_feature = normalizer(feature)
    return norm_feature

# %% [markdown]
# Now we can apply these functions to each of our features and return an encoded/preprocessed input layer. We first create tensor variables for each of the inputs, then apply the appropriate function, then concatenate all of these input layers for each feature together to form a single input feature layer.

# %%
all_inputs = [
    keras.Input(shape=(1,), name="sex", dtype="int64"),
    keras.Input(shape=(1,), name="cp", dtype="int64"),
    keras.Input(shape=(1,), name="fbs", dtype="int64"),
    keras.Input(shape=(1,), name="restecg", dtype="int64"),
    keras.Input(shape=(1,), name="exang", dtype="int64"),
    keras.Input(shape=(1,), name="ca", dtype="int64"),
    keras.Input(shape=(1,), name="thal", dtype="string"),
    keras.Input(shape=(1,), name="age"),
    keras.Input(shape=(1,), name="trestbps"),
    keras.Input(shape=(1,), name="chol"),
    keras.Input(shape=(1,), name="thalach"),
    keras.Input(shape=(1,), name="oldpeak"),
    keras.Input(shape=(1,), name="slope"),
]

# %%
feature_layer = layers.concatenate(
    [
        encode_categorical_feature(all_inputs[0], "sex", train_ds, False),
        encode_categorical_feature(all_inputs[1], "cp", train_ds, False),
        encode_categorical_feature(all_inputs[2], "fbs", train_ds, False),
        encode_categorical_feature(all_inputs[3], "restecg", train_ds, False),
        encode_categorical_feature(all_inputs[4], "exang", train_ds, False),
        encode_categorical_feature(all_inputs[5], "ca", train_ds, False),
        encode_categorical_feature(all_inputs[6], "thal", train_ds, True),
        normalize(all_inputs[7], "age", train_ds),
        normalize(all_inputs[8], "trestbps", train_ds),
        normalize(all_inputs[9], "chol", train_ds),
        normalize(all_inputs[10], "thalach", train_ds),
        normalize(all_inputs[11], "oldpeak", train_ds),
        normalize(all_inputs[12], "slope", train_ds)
    ]
)

# %% [markdown]
# ### Build the model
#
# Now that we've prepared our dataset, we can construct our neural network model. We construct the model by composing Layer objects starting with the input layer (which we've already defined as `feature_layer`) and ending with the output layer (which will be the final output of the model). In this example, we will only use [Dense()](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) layers which are simple fully-connected feed-forward layers (i.e., each output from layer `i-1` is connected by a weight variable to every neuron in layer `i`). We will create a network with only one hidden layer (between the input and output layers).
#
# The Dense() layer object allows us to specify the activation function to use using the `activation` argument. In class, we talked about several activation functions including sigmoid, sign, and tanh. Another commonly used activation function is the rectified linear unit, or "ReLU" function. Another commonly used activation function is the rectified linear unit, or "ReLU" function, which has the equation $a(z)=max(0,z)$. We will use `relu` as our activation function in this example for all layers except the final layer, which will use a `sigmoid` activation.

# %%
# Create a variable for the number of units/neurons in the layer
h1_units = 32
# Create a Dense layer and append it to the input layer
h1_layer = layers.Dense(h1_units, activation='relu')(feature_layer)

# Create an output layer with one output representing the likelihood of
# heart disease and append it to the hidden layer
output_layer = layers.Dense(1, activation="sigmoid")(h1_layer)

# Build the model specifying the input and output layer
model = keras.Model(inputs=all_inputs, outputs=output_layer)

# %% [markdown]
# We can plot our completed model to visualize the input, hidden, and output layers.

# %%
# `rankdir='LR'` is to make the graph horizontal
keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# Next we compile the model by specifying the optimization technique and loss function to be used in model training. We can also specify the metric(s) that will be logged during training. We will use stochastic gradient descent (`sgd`) for the optimizer and binary cross entropy (log loss) as the loss function. We will log the accuracy metric during training. We can also specify the learning rate hyperparameter here.

# %%
learning_rate = 0.01
model.compile(keras.optimizers.SGD(learning_rate=learning_rate), "binary_crossentropy", metrics=["accuracy"])

# %% [markdown]
# ### Train the model
#
# Now that we've constructed and compiled our model, we can train the model using our training dataset. This is done in keras using the `fit()` function, which also gives us an option to provide the validation dataset which will be used to evaluate validation accuracy after every epoch.

# %%
model_result = model.fit(train_ds, epochs=100, validation_data=val_ds)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 3s 169ms/step - loss: 0.7766 - accuracy: 0.4088 - val_loss: 0.7059 - val_accuracy: 0.5246
# Epoch 2/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.7353 - accuracy: 0.4751 - val_loss: 0.6773 - val_accuracy: 0.6066
# Epoch 3/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.7006 - accuracy: 0.5746 - val_loss: 0.6532 - val_accuracy: 0.6230
# Epoch 4/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6710 - accuracy: 0.6464 - val_loss: 0.6327 - val_accuracy: 0.6066
# Epoch 5/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6457 - accuracy: 0.6519 - val_loss: 0.6152 - val_accuracy: 0.6066
# Epoch 6/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.6238 - accuracy: 0.6796 - val_loss: 0.5999 - val_accuracy: 0.6230
# Epoch 7/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6048 - accuracy: 0.7017 - val_loss: 0.5865 - val_accuracy: 0.6721
# Epoch 8/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5881 - accuracy: 0.7127 - val_loss: 0.5746 - val_accuracy: 0.7213
# Epoch 9/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5733 - accuracy: 0.7293 - val_loss: 0.5640 - val_accuracy: 0.7377
# Epoch 10/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5600 - accuracy: 0.7182 - val_loss: 0.5545 - val_accuracy: 0.7377
# Epoch 11/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5481 - accuracy: 0.7403 - val_loss: 0.5459 - val_accuracy: 0.7377
# Epoch 12/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5372 - accuracy: 0.7459 - val_loss: 0.5380 - val_accuracy: 0.7541
# Epoch 13/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5273 - accuracy: 0.7459 - val_loss: 0.5308 - val_accuracy: 0.7541
# Epoch 14/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5183 - accuracy: 0.7569 - val_loss: 0.5240 - val_accuracy: 0.7541
# Epoch 15/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5099 - accuracy: 0.7624 - val_loss: 0.5177 - val_accuracy: 0.7377
# Epoch 16/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5022 - accuracy: 0.7680 - val_loss: 0.5119 - val_accuracy: 0.7377
# Epoch 17/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4950 - accuracy: 0.7680 - val_loss: 0.5063 - val_accuracy: 0.7377
# Epoch 18/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4882 - accuracy: 0.7735 - val_loss: 0.5011 - val_accuracy: 0.7377
# Epoch 19/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4819 - accuracy: 0.7735 - val_loss: 0.4962 - val_accuracy: 0.7377
# Epoch 20/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4759 - accuracy: 0.7680 - val_loss: 0.4915 - val_accuracy: 0.7377
# Epoch 21/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4702 - accuracy: 0.7735 - val_loss: 0.4871 - val_accuracy: 0.7377
# Epoch 22/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4648 - accuracy: 0.7735 - val_loss: 0.4828 - val_accuracy: 0.7377
# Epoch 23/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4597 - accuracy: 0.7735 - val_loss: 0.4788 - val_accuracy: 0.7377
# Epoch 24/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4548 - accuracy: 0.7735 - val_loss: 0.4749 - val_accuracy: 0.7377
# Epoch 25/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4501 - accuracy: 0.7790 - val_loss: 0.4712 - val_accuracy: 0.7377
# Epoch 26/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4457 - accuracy: 0.7845 - val_loss: 0.4677 - val_accuracy: 0.7377
# Epoch 27/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.4414 - accuracy: 0.7845 - val_loss: 0.4642 - val_accuracy: 0.7213
# Epoch 28/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4373 - accuracy: 0.7790 - val_loss: 0.4610 - val_accuracy: 0.7213
# Epoch 29/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4333 - accuracy: 0.7790 - val_loss: 0.4578 - val_accuracy: 0.7377
# Epoch 30/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.4296 - accuracy: 0.7790 - val_loss: 0.4548 - val_accuracy: 0.7377
# Epoch 31/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4259 - accuracy: 0.7735 - val_loss: 0.4519 - val_accuracy: 0.7377
# Epoch 32/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4224 - accuracy: 0.7790 - val_loss: 0.4491 - val_accuracy: 0.7377
# Epoch 33/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4190 - accuracy: 0.7790 - val_loss: 0.4463 - val_accuracy: 0.7377
# Epoch 34/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.4158 - accuracy: 0.7845 - val_loss: 0.4437 - val_accuracy: 0.7377
# Epoch 35/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4126 - accuracy: 0.7901 - val_loss: 0.4412 - val_accuracy: 0.7377
# Epoch 36/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4096 - accuracy: 0.7901 - val_loss: 0.4387 - val_accuracy: 0.7377
# Epoch 37/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4067 - accuracy: 0.7845 - val_loss: 0.4363 - val_accuracy: 0.7541
# Epoch 38/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4038 - accuracy: 0.7790 - val_loss: 0.4340 - val_accuracy: 0.7869
# Epoch 39/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4010 - accuracy: 0.7845 - val_loss: 0.4318 - val_accuracy: 0.8033
# Epoch 40/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3984 - accuracy: 0.7901 - val_loss: 0.4296 - val_accuracy: 0.8197
# Epoch 41/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.3958 - accuracy: 0.7901 - val_loss: 0.4275 - val_accuracy: 0.8197
# Epoch 42/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3932 - accuracy: 0.7956 - val_loss: 0.4255 - val_accuracy: 0.8197
# Epoch 43/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.3908 - accuracy: 0.7956 - val_loss: 0.4236 - val_accuracy: 0.8197
# Epoch 44/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3884 - accuracy: 0.7956 - val_loss: 0.4217 - val_accuracy: 0.8197
# Epoch 45/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3861 - accuracy: 0.7956 - val_loss: 0.4198 - val_accuracy: 0.8197
# Epoch 46/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3839 - accuracy: 0.7901 - val_loss: 0.4180 - val_accuracy: 0.8197
# Epoch 47/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3817 - accuracy: 0.7901 - val_loss: 0.4163 - val_accuracy: 0.8197
# Epoch 48/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3796 - accuracy: 0.7956 - val_loss: 0.4146 - val_accuracy: 0.8361
# Epoch 49/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3775 - accuracy: 0.7956 - val_loss: 0.4130 - val_accuracy: 0.8361
# Epoch 50/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3755 - accuracy: 0.8011 - val_loss: 0.4114 - val_accuracy: 0.8361
# Epoch 51/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3736 - accuracy: 0.8011 - val_loss: 0.4099 - val_accuracy: 0.8361
# Epoch 52/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3717 - accuracy: 0.7956 - val_loss: 0.4084 - val_accuracy: 0.8525
# Epoch 53/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3699 - accuracy: 0.7956 - val_loss: 0.4070 - val_accuracy: 0.8525
# Epoch 54/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3681 - accuracy: 0.7956 - val_loss: 0.4056 - val_accuracy: 0.8525
# Epoch 55/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3663 - accuracy: 0.7956 - val_loss: 0.4042 - val_accuracy: 0.8525
# Epoch 56/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3646 - accuracy: 0.8011 - val_loss: 0.4029 - val_accuracy: 0.8525
# Epoch 57/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3629 - accuracy: 0.8011 - val_loss: 0.4016 - val_accuracy: 0.8525
# Epoch 58/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3613 - accuracy: 0.7956 - val_loss: 0.4003 - val_accuracy: 0.8525
# Epoch 59/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3597 - accuracy: 0.7956 - val_loss: 0.3991 - val_accuracy: 0.8525
# Epoch 60/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3581 - accuracy: 0.8066 - val_loss: 0.3979 - val_accuracy: 0.8525
# Epoch 61/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3566 - accuracy: 0.8177 - val_loss: 0.3967 - val_accuracy: 0.8525
# Epoch 62/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3551 - accuracy: 0.8232 - val_loss: 0.3956 - val_accuracy: 0.8525
# Epoch 63/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3537 - accuracy: 0.8232 - val_loss: 0.3945 - val_accuracy: 0.8525
# Epoch 64/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3523 - accuracy: 0.8232 - val_loss: 0.3934 - val_accuracy: 0.8525
# Epoch 65/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3509 - accuracy: 0.8232 - val_loss: 0.3924 - val_accuracy: 0.8525
# Epoch 66/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.3495 - accuracy: 0.8232 - val_loss: 0.3913 - val_accuracy: 0.8525
# Epoch 67/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3482 - accuracy: 0.8287 - val_loss: 0.3903 - val_accuracy: 0.8525
# Epoch 68/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3469 - accuracy: 0.8287 - val_loss: 0.3893 - val_accuracy: 0.8525
# Epoch 69/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3457 - accuracy: 0.8287 - val_loss: 0.3884 - val_accuracy: 0.8525
# Epoch 70/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3445 - accuracy: 0.8398 - val_loss: 0.3874 - val_accuracy: 0.8525
# Epoch 71/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3433 - accuracy: 0.8398 - val_loss: 0.3865 - val_accuracy: 0.8525
# Epoch 72/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3421 - accuracy: 0.8398 - val_loss: 0.3856 - val_accuracy: 0.8525
# Epoch 73/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3409 - accuracy: 0.8398 - val_loss: 0.3847 - val_accuracy: 0.8525
# Epoch 74/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3398 - accuracy: 0.8398 - val_loss: 0.3838 - val_accuracy: 0.8525
# Epoch 75/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3387 - accuracy: 0.8453 - val_loss: 0.3830 - val_accuracy: 0.8525
# Epoch 76/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.3376 - accuracy: 0.8453 - val_loss: 0.3821 - val_accuracy: 0.8525
# Epoch 77/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3366 - accuracy: 0.8453 - val_loss: 0.3813 - val_accuracy: 0.8525
# Epoch 78/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3355 - accuracy: 0.8453 - val_loss: 0.3805 - val_accuracy: 0.8525
# Epoch 79/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3345 - accuracy: 0.8508 - val_loss: 0.3798 - val_accuracy: 0.8525
# Epoch 80/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3335 - accuracy: 0.8508 - val_loss: 0.3790 - val_accuracy: 0.8525
# Epoch 81/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3325 - accuracy: 0.8508 - val_loss: 0.3783 - val_accuracy: 0.8525
# Epoch 82/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3316 - accuracy: 0.8508 - val_loss: 0.3775 - val_accuracy: 0.8525
# Epoch 83/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3306 - accuracy: 0.8508 - val_loss: 0.3768 - val_accuracy: 0.8525
# Epoch 84/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3297 - accuracy: 0.8508 - val_loss: 0.3761 - val_accuracy: 0.8525
# Epoch 85/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3288 - accuracy: 0.8508 - val_loss: 0.3755 - val_accuracy: 0.8525
# Epoch 86/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3279 - accuracy: 0.8508 - val_loss: 0.3748 - val_accuracy: 0.8525
# Epoch 87/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3270 - accuracy: 0.8508 - val_loss: 0.3742 - val_accuracy: 0.8525
# Epoch 88/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3261 - accuracy: 0.8508 - val_loss: 0.3735 - val_accuracy: 0.8525
# Epoch 89/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.3253 - accuracy: 0.8508 - val_loss: 0.3729 - val_accuracy: 0.8525
# Epoch 90/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3244 - accuracy: 0.8508 - val_loss: 0.3723 - val_accuracy: 0.8525
# Epoch 91/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3236 - accuracy: 0.8508 - val_loss: 0.3717 - val_accuracy: 0.8525
# Epoch 92/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3228 - accuracy: 0.8508 - val_loss: 0.3711 - val_accuracy: 0.8525
# Epoch 93/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3219 - accuracy: 0.8508 - val_loss: 0.3705 - val_accuracy: 0.8525
# Epoch 94/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3212 - accuracy: 0.8564 - val_loss: 0.3699 - val_accuracy: 0.8525
# Epoch 95/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3203 - accuracy: 0.8564 - val_loss: 0.3693 - val_accuracy: 0.8525
# Epoch 96/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3196 - accuracy: 0.8564 - val_loss: 0.3688 - val_accuracy: 0.8525
# Epoch 97/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3188 - accuracy: 0.8564 - val_loss: 0.3682 - val_accuracy: 0.8525
# Epoch 98/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3180 - accuracy: 0.8564 - val_loss: 0.3677 - val_accuracy: 0.8525
# Epoch 99/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3173 - accuracy: 0.8564 - val_loss: 0.3672 - val_accuracy: 0.8525
# Epoch 100/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3165 - accuracy: 0.8564 - val_loss: 0.3667 - val_accuracy: 0.8525

# %% [markdown]
# The `fit()` function returns a history attribute that gives the metrics recorded during training as a dictionary. We can print the dictionary keys to see which metrics were stored:

# %%
model_result.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Create a figure with two subplots. The first subplot should plot the training and validation loss (`loss` and `val_loss`) and the second subplot should plot the training and validation accuracy (`accuracy` and `val_accuracy`). Make sure you include the axis labels and a legend in each plot.

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

# YOUR CODE HERE
print(model_result.history)
ax1.plot(model_result.history['loss'], label='Training Loss')
ax1.plot(model_result.history['val_loss'], label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

# Plotting training and validation accuracy
ax2.plot(model_result.history['accuracy'], label='Training Accuracy')
ax2.plot(model_result.history['val_accuracy'], label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# {'loss': [0.7766093015670776, 0.7353217005729675, 0.7006151080131531, 0.6709898710250854, 0.6456736922264099, 0.623842716217041, 0.604781448841095, 0.5880966782569885, 0.5732625722885132, 0.5600139498710632, 0.548076331615448, 0.5372270345687866, 0.527330219745636, 0.5182660818099976, 0.5099138021469116, 0.5021756291389465, 0.494960218667984, 0.48821237683296204, 0.4818733036518097, 0.47590145468711853, 0.47022703289985657, 0.46482765674591064, 0.459668904542923, 0.4547703266143799, 0.45011666417121887, 0.44565442204475403, 0.44136831164360046, 0.4372628927230835, 0.43334144353866577, 0.42956244945526123, 0.4259302616119385, 0.4224300980567932, 0.41904398798942566, 0.41578784584999084, 0.4126482903957367, 0.40959739685058594, 0.4066534638404846, 0.4038012623786926, 0.40104296803474426, 0.3983684480190277, 0.39576661586761475, 0.3932372033596039, 0.3907897174358368, 0.38842064142227173, 0.3861166536808014, 0.38387125730514526, 0.3816966712474823, 0.3795759081840515, 0.3775097727775574, 0.3755049705505371, 0.3735683858394623, 0.3716869354248047, 0.3698560297489166, 0.3680669963359833, 0.3663053512573242, 0.36457791924476624, 0.36289262771606445, 0.36125895380973816, 0.35966652631759644, 0.35811445116996765, 0.3565973937511444, 0.35511523485183716, 0.3536694347858429, 0.3522639870643616, 0.35089123249053955, 0.34954527020454407, 0.34823089838027954, 0.3469451665878296, 0.3456933796405792, 0.3444674611091614, 0.34326687455177307, 0.34209007024765015, 0.3409377336502075, 0.3398091495037079, 0.33870282769203186, 0.3376186788082123, 0.3365562856197357, 0.3355152904987335, 0.334495484828949, 0.33349865674972534, 0.33252230286598206, 0.33156365156173706, 0.3306191861629486, 0.32968631386756897, 0.3287702798843384, 0.3278706967830658, 0.3269835114479065, 0.3261130154132843, 0.32525500655174255, 0.32441195845603943, 0.3235785663127899, 0.32275623083114624, 0.3219439387321472, 0.32115060091018677, 0.32034704089164734, 0.31955820322036743, 0.3187783658504486, 0.3180120587348938, 0.3172547221183777, 0.31651735305786133], 'accuracy': [0.40883979201316833, 0.4751381278038025, 0.5745856165885925, 0.6464088559150696, 0.6519337296485901, 0.6795580387115479, 0.7016574740409851, 0.7127071619033813, 0.7292817831039429, 0.7182320356369019, 0.7403314709663391, 0.7458563446998596, 0.7458563446998596, 0.7569060921669006, 0.7624309659004211, 0.7679557800292969, 0.7679557800292969, 0.7734806537628174, 0.7734806537628174, 0.7679557800292969, 0.7734806537628174, 0.7734806537628174, 0.7734806537628174, 0.7734806537628174, 0.7790055274963379, 0.7845304012298584, 0.7845304012298584, 0.7790055274963379, 0.7790055274963379, 0.7790055274963379, 0.7734806537628174, 0.7790055274963379, 0.7790055274963379, 0.7845304012298584, 0.7900552749633789, 0.7900552749633789, 0.7845304012298584, 0.7790055274963379, 0.7845304012298584, 0.7900552749633789, 0.7900552749633789, 0.7955800890922546, 0.7955800890922546, 0.7955800890922546, 0.7955800890922546, 0.7900552749633789, 0.7900552749633789, 0.7955800890922546, 0.7955800890922546, 0.8011049628257751, 0.8011049628257751, 0.7955800890922546, 0.7955800890922546, 0.7955800890922546, 0.7955800890922546, 0.8011049628257751, 0.8011049628257751, 0.7955800890922546, 0.7955800890922546, 0.8066298365592957, 0.8176795840263367, 0.8232043981552124, 0.8232043981552124, 0.8232043981552124, 0.8232043981552124, 0.8232043981552124, 0.8287292718887329, 0.8287292718887329, 0.8287292718887329, 0.8397790193557739, 0.8397790193557739, 0.8397790193557739, 0.8397790193557739, 0.8397790193557739, 0.8453038930892944, 0.8453038930892944, 0.8453038930892944, 0.8453038930892944, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8508287072181702, 0.8563535809516907, 0.8563535809516907, 0.8563535809516907, 0.8563535809516907, 0.8 ...

# %% [markdown]
# ### Test the model
#
# Finally, we evaluate our trained model on the held-out test set. First we predict the outputs for the test data.

# %%
preds = model.predict(test_ds)
# Out:
# 1/1 [==============================] - 0s 409ms/step

# %% [markdown]
# The model output from the final sigmoid layer is a value between 0 and 1 representing the likelihood that a given sample patient has heart disease. To get the predicted classes, we predict 1 if the output was >= 0.5 and 0 otherwise.

# %%
pred_classes = [1 if p >= 0.5 else 0 for p in preds]

# %% [markdown]
# Compute and print the test accuracy.

# %%
from sklearn.metrics import accuracy_score

# YOUR CODE HERE
# test_labels = np.array(test['target'])
test_labels = [j.numpy() for i,j in test_ds][0]
test_accuracy = accuracy_score(test_labels, pred_classes)
print("Test accuracy:", test_accuracy)
print("Training Accuracy",model_result.history['accuracy'][-1])
print("Validation Accuracy",model_result.history['val_accuracy'][-1])
# Out:
# Test accuracy: 0.8032786885245902
# Training Accuracy 0.8563535809516907
# Validation Accuracy 0.8524590134620667

# %% [markdown]
# **Question 1: There is a large difference between the training and validation accuracies and the test accuracy. What do you think could explain this difference?**
#
# **Answer:**
#
# The partitioning of data into training, test, and validation sets might effect its accuracy. The test data may not be consistent with the remainder of the dataset. The model's ability to generalise to the test set may be limited due to overfitting.

# %% [markdown]
# ## Hyperparameter tuning with K-fold Cross Validation

# %% [markdown]
# ### k-fold Cross validation
#
# We will use 5-fold cross validation to train and evaluate our classifier. We will not do any model selection/hyperparameter tuning in this step, so we need to split our data into a training and test set.
#
# To split the data into 3 folds we will shuffle the rows and then split them into $k$ equal groups.

# %%
k = 3

# Note: np.split raises error if indices_or_sections is
# an integer and doesn't result in equal size splits
folds = np.split(data.sample(frac=1, random_state=seed), indices_or_sections=k)

# %% [markdown]
# Use a for loop to print the number of samples and number of samples from each class in each fold.

# %%
folds[0][folds[0]['target']==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 225   58    0   4       130   197    0        0      131      0      0.6
# 201   43    1   4       115   303    0        0      181      0      1.2
# 52    53    0   4       130   264    0        2      143      0      0.4
# 168   54    0   3       108   267    0        2      167      0      0.0
# 223   39    0   3       138   220    0        0      152      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 247   59    1   0       164   176    1        0       90      0      1.0
# 288   57    0   4       128   303    0        2      159      0      0.0
# 156   62    0   4       150   244    0        0      154      1      1.4
# 297   56    1   4       125   249    1        2      144      1      1.2
# 252   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca    thal  target
# 225      2   0  normal       0
# 201      2   0  normal       0
# 52       2   0  normal       0
# 168      1   0  normal       0
# 223      2   0  normal       0
# ..     ...  ..     ...     ...
# 247      1   2       1       0
# 288      1   1  normal       0
# 156      2   0  normal       0
# 297      2   1  normal       0
# 252      1   1       2       0
#
# [75 rows x 14 columns]

# %%
# YOUR CODE HERE
k=3
# Shuffle the rows of the data and split them into k equal groups (folds)
folds = np.split(data.sample(frac=1, random_state=seed), indices_or_sections=k)
# Print the number of samples and the number of samples from each class in each fold
for fold_idx, fold_data in enumerate(folds):
  print(f"Fold {fold_idx + 1}:")
  total_samples = len(fold_data)
  heart_disease_samples = len(fold_data[fold_data['target'] == 1])
  no_disease_samples = len(fold_data[fold_data['target'] == 0])
  print(f"Total samples: {total_samples}")
  print(f"Heart disease samples: {heart_disease_samples}")
  print(f"No disease samples: {no_disease_samples}")
  print()
# Out:
# Fold 1:
# Total samples: 101
# Heart disease samples: 26
# No disease samples: 75
#
# Fold 2:
# Total samples: 101
# Heart disease samples: 27
# No disease samples: 74
#
# Fold 3:
# Total samples: 101
# Heart disease samples: 30
# No disease samples: 71

# %% [markdown]
# ### Train a Neural Network classifier
#
# We will use the Neural Network (NN) implemented in previous section for our classification model. Use cross validation to train and evaluate the model. Set hyperparameters to `h1_units=32` and `h1_activation='relu'`, and tune the hypaerparameter `learning_rate` with candidate values `[0.01, 0.03]`.
#
# Implement a for loop to iterate hyperparameters, and then implement another for loop to iterate through each fold, training a new NN model each iteration with one fold assigned to validation and the remaining folds assigned to training. Compute the validation accuracy for each iteration and append it to the `accuracies` list.

# %%
from sklearn.metrics import accuracy_score

def create_model(h1_units, learning_rate, h1_activation):
  all_inputs = [
    keras.Input(shape=(1,), name="sex", dtype="int64"),
    keras.Input(shape=(1,), name="cp", dtype="int64"),
    keras.Input(shape=(1,), name="fbs", dtype="int64"),
    keras.Input(shape=(1,), name="restecg", dtype="int64"),
    keras.Input(shape=(1,), name="exang", dtype="int64"),
    keras.Input(shape=(1,), name="ca", dtype="int64"),
    keras.Input(shape=(1,), name="thal", dtype="string"),
    keras.Input(shape=(1,), name="age"),
    keras.Input(shape=(1,), name="trestbps"),
    keras.Input(shape=(1,), name="chol"),
    keras.Input(shape=(1,), name="thalach"),
    keras.Input(shape=(1,), name="oldpeak"),
    keras.Input(shape=(1,), name="slope"),
  ]
  feature_layer = layers.concatenate(
    [
        encode_categorical_feature(all_inputs[0], "sex", train_ds, False),
        encode_categorical_feature(all_inputs[1], "cp", train_ds, False),
        encode_categorical_feature(all_inputs[2], "fbs", train_ds, False),
        encode_categorical_feature(all_inputs[3], "restecg", train_ds, False),
        encode_categorical_feature(all_inputs[4], "exang", train_ds, False),
        encode_categorical_feature(all_inputs[5], "ca", train_ds, False),
        encode_categorical_feature(all_inputs[6], "thal", train_ds, True),
        normalize(all_inputs[7], "age", train_ds),
        normalize(all_inputs[8], "trestbps", train_ds),
        normalize(all_inputs[9], "chol", train_ds),
        normalize(all_inputs[10], "thalach", train_ds),
        normalize(all_inputs[11], "oldpeak", train_ds),
        normalize(all_inputs[12], "slope", train_ds)
    ]
  )
  h1_layer = layers.Dense(h1_units, activation=h1_activation)(feature_layer)
  output_layer = layers.Dense(1, activation="sigmoid")(h1_layer)
  model = keras.Model(inputs=all_inputs, outputs=output_layer)
  model.compile(keras.optimizers.SGD(learning_rate=learning_rate), "binary_crossentropy", metrics=["accuracy"])
  return model


h1_units=32
learning_rate=[0.01, 0.03]
h1_activation='relu'

accuracies = []

for lr in learning_rate:
  accuracies_per_param = []

  for i in range(len(folds)):
      # assign the folds to training and validation
      train = pd.concat(folds[0:i] + folds[i+1:])
      val = folds[i]
      train_ds_original = dataframe_to_dataset(train)
      val_ds_original = dataframe_to_dataset(val, shuffle=False)

      train_ds = train_ds_original.batch(32)
      val_ds = val_ds_original.batch(val.shape[0])

      model = create_model(h1_units, lr, h1_activation)

      model_result = model.fit(train_ds, epochs=10, validation_data=val_ds)

      # predict test set, the output is a probability, not an integer
      pred_val = model.predict(val_ds)

      # YOUR CODE HERE
      # convert the probability to integer - the class label
      pred_labels = [1 if p >= 0.5 else 0 for p in pred_val]
# Calculate and append accuracy to accuracies_per_param list
      true_labels = [y.numpy() for x, y in val_ds][0]
      accuracy = accuracy_score(true_labels, pred_labels)
      accuracies_per_param.append(accuracy)

      # append accuracy to accuracies_per_param list


  accuracies.append(accuracies_per_param)
for i, lr in enumerate(learning_rate):
  print(f"Learning Rate = {lr}:")
  for fold_idx, accuracy in enumerate(accuracies[i]):
    print(f"Fold {fold_idx + 1} Accuracy: {accuracy:.4f}")
  print()
# Out:
# Epoch 1/10
# 7/7 [==============================] - 1s 55ms/step - loss: 0.7916 - accuracy: 0.3218 - val_loss: 0.7519 - val_accuracy: 0.3663
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7343 - accuracy: 0.4406 - val_loss: 0.6933 - val_accuracy: 0.5149
# Epoch 3/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6888 - accuracy: 0.5644 - val_loss: 0.6463 - val_accuracy: 0.6139
# Epoch 4/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6522 - accuracy: 0.6337 - val_loss: 0.6081 - val_accuracy: 0.7129
# Epoch 5/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6222 - accuracy: 0.6931 - val_loss: 0.5765 - val_accuracy: 0.7426
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5973 - accuracy: 0.7376 - val_loss: 0.5501 - val_accuracy: 0.7921
# Epoch 7/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5761 - accuracy: 0.7426 - val_loss: 0.5276 - val_accuracy: 0.8119
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5580 - accuracy: 0.7426 - val_loss: 0.5083 - val_accuracy: 0.8119
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5422 - accuracy: 0.7574 - val_loss: 0.4916 - val_accuracy: 0.8218
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.7673 - val_loss: 0.4769 - val_accuracy: 0.8416
# 1/1 [==============================] - 0s 229ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 56ms/step - loss: 0.6644 - accuracy: 0.6287 - val_loss: 0.6332 - val_accuracy: 0.7228
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6492 - accuracy: 0.6436 - val_loss: 0.6215 - val_accuracy: 0.7426
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6351 - accuracy: 0.6485 - val_loss: 0.6106 - val_accuracy: 0.7624
# Epoch 4/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6220 - accuracy: 0.6733 - val_loss: 0.6005 - val_accuracy: 0.7624
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6098 - accuracy: 0.6782 - val_loss: 0.5912 - val_accuracy: 0.7624
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5984 - accuracy: 0.6832 - val_loss: 0.5824 - val_accuracy: 0.7624
# Epoch 7/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5876 - accuracy: 0.6881 - val_loss: 0.5741 - val_accuracy: 0.7624
# Epoch 8/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5773 - accuracy: 0.6980 - val_loss: 0.5663 - val_accuracy: 0.7723
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5676 - accuracy: 0.6980 - val_loss: 0.5589 - val_accuracy: 0.7624
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5583 - accuracy: 0.7030 - val_loss: 0.5519 - val_accuracy: 0.7723
# 1/1 [==============================] - 0s 253ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 56ms/step - loss: 0.6743 - accuracy: 0.5644 - val_loss: 0.6634 - val_accuracy: 0.6337
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6473 - accuracy: 0.6287 - val_loss: 0.6427 - val_accuracy: 0.6733
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6243 - accuracy: 0.6683 - val_loss: 0.6250 - val_accuracy: 0.6832
# Epoch 4/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6043 - accuracy: 0.6980 - val_loss: 0.6096 - val_accuracy: 0.6733
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5869 - accuracy: 0.7079 - val_loss: 0.5961 - val_accuracy: 0.6733
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5714 - accuracy: 0.7129 - val_loss: 0.5840 - val_accuracy: 0.6832
# Epoch 7/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5576 - accuracy: 0.7277 - val_loss: 0.5733 - val_accuracy: 0.6832
# Epoch 8/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5453 - accuracy: 0.7475 - val_loss: 0.5638 - val_accuracy: 0.6931
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5341 - accuracy: 0.7475 - val_loss: 0.5552 - val_accuracy: 0.7129
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5240 - accuracy: 0.7426 - val_loss: 0.5474 - val_accuracy: 0.7228
# 1/1 [==============================] - 0s 227ms/step
# Epoch 1/10
# 7/7 [==============================] - 2s 57ms/step - loss: 0.8209 - accuracy: 0.2723 - val_loss: 0.7535 - val_accuracy: 0.3564
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6965 - accuracy: 0.5347 - val_loss: 0.6531 - val_accuracy: 0.6634
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6282 - accuracy: 0.7228 - val_loss: 0.5905 - val_accuracy: 0.7822
# Epoch 4/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5843 - accuracy: 0.7475 - val_loss: 0.5472 - val_accuracy: 0.7822
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5527 - accuracy: 0.7624 - val_loss: 0.5146 - val_accuracy: 0.7921
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5282 - accuracy: 0.7673 - val_loss: 0.4886 - val_accuracy: 0.8020
# Epoch 7/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7624 - val_loss: 0.4670 - val_accuracy: 0.8119
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4910 - accuracy: 0.7723 - val_loss: 0.4487 - val_accuracy: 0.8119
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4763 - accuracy: 0.7723 - val_loss: 0.4327 - val_accuracy: 0.8020
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4633 - accuracy: 0.7822 - val_loss: 0.4188 - val_accuracy: 0.8218
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x798075430ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 237ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 54ms/step - loss: 0.7491 - accuracy: 0.4307 - val_loss: 0.6914 - val_accuracy: 0.5743
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6187 - accuracy: 0.6733 - val_loss: 0.6013 - val_accuracy: 0.7030
# Epoch 3/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5439 - accuracy: 0.7921 - val_loss: 0.5473 - val_accuracy: 0.7426
# Epoch 4/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4964 - accuracy: 0.8020 - val_loss: 0.5132 - val_accuracy: 0.7723
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4648 - accuracy: 0.8168 - val_loss: 0.4904 - val_accuracy: 0.7921
# Epoch 6/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.8218 - val_loss: 0.4743 - val_accuracy: 0.7723
# Epoch 7/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4250 - accuracy: 0.8218 - val_loss: 0.4624 - val_accuracy: 0.7723
# Epoch 8/10
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4111 - accuracy: 0.8119 - val_loss: 0.4530 - val_accuracy: 0.7723
# Epoch 9/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3995 - accuracy: 0.8069 - val_loss: 0.4455 - val_accuracy: 0.7624
# Epoch 10/10
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3894 - accuracy: 0.8069 - val_loss: 0.4391 - val_accuracy: 0.7624
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x79807622af80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 355ms/step
# Epoch 1/10
# 7/7 [==============================] - 1s 58ms/step - loss: 0.6388 - accuracy: 0.6782 - val_loss: 0.6216 - val_accuracy: 0.7525
# Epoch 2/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5900 - accuracy: 0.7327 - val_loss: 0.5883 - val_accuracy: 0.7525
# Epoch 3/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5544 - accuracy: 0.7376 - val_loss: 0.5627 - val_accuracy: 0.7525
# Epoch 4/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7475 - val_loss: 0.5418 - val_accuracy: 0.7426
# Epoch 5/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5039 - accuracy: 0.7624 - val_loss: 0.5239 - val_accuracy: 0.7228
# Epoch 6/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4849 - accuracy: 0.7772 - val_loss: 0.5081 - val_accuracy: 0.7228
# Epoch 7/10
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4685 - accuracy: 0.7822 - val_loss: 0.4938 - val_accuracy: 0.7426
# Epoch 8/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4541 - accuracy: 0.7822 - val_loss: 0.4809 - val_accuracy: 0.7426
# Epoch 9/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4413 - accuracy: 0.7871 - val_loss: 0.4691 - val_accuracy: 0.7525
# Epoch 10/10
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4299 - accuracy: 0.7921 - val_loss: 0.4586 - val_accuracy: 0.7525
# 1/1 [==============================] - 0s 246ms/step
# Learning Rate = 0.01:
# Fold 1 Accuracy: 0.8416
# Fold 2 Accuracy: 0.7723
# Fold 3 Accuracy: 0.7228
#
# Learning Rate = 0.03:
# Fold 1 Accuracy: 0.8218
# Fold 2 Accuracy: 0.7624
# Fold 3 Accuracy: 0.7525

# %% [markdown]
# **Question 2: How many total combinations of the above hyperparameter choices are there?**
#
# **Answer:**
#
# 2 total combinations, as we are only varying the learning rate

# %% [markdown]
# Print the mean and standard deviation of the accuracy from cross validation for all hyperparams(across all $k$ folds).

# %%
print(accuracies)
acc_mean = np.mean(accuracies, axis=1)
acc_std = np.std(accuracies, axis=1)

print(pd.DataFrame.from_dict(
    { "Params": learning_rate,
    "Accucary Mean": acc_mean,
    "Accucary Std ": acc_std,
}) )
# Out:
# [[0.8415841584158416, 0.7722772277227723, 0.7227722772277227], [0.8217821782178217, 0.7623762376237624, 0.7524752475247525]]
#    Params  Accucary Mean  Accucary Std
# 0    0.01       0.778878       0.048729
# 1    0.03       0.778878       0.030606

# %% [markdown]
# **Question 3: If you increased the number of folds, do you expect the standard deviation of the accuracy across $k$ folds to increase or decrease? Why?**
#
# **Answer:**
#
# Increasing the number of folds in k-fold cross-validation may result in higher standard deviation of accuracy across folds due to fewer samples per fold during training.
